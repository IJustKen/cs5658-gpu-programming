# %%
# !nvcc q2.cu -o q2
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q2
# Out:
# Depositing money across 4 blocks..
#
# [BLOCK 2] Step 1 Finished, Waiting for Others..
#
# [BLOCK 0] Step 1 Finished, Waiting for Others..
#
# [BLOCK 1] Step 1 Finished, Waiting for Others..
#
# [BLOCK 3] Step 1 Finished, Waiting for Others..
#
# [VERIFICATION] Block 1 reads total balance: Rs.2560
# [VERIFICATION] Block 0 reads total balance: Rs.2560
# [VERIFICATION] Block 2 reads total balance: Rs.2560
# [VERIFICATION] Block 3 reads total balance: Rs.2560
